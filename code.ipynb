# %% [markdown]
# # <span style='font-family:new roman'>Project ML: Titanic : machine learning from disaster</span>

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 660.6 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.6 MB 1.3 MB/s eta 0:00:08
#     --------------------------------------- 0.2/10.6 MB 1.8 MB/s eta 0:00:06
#     --------------------------------------- 0.2/10.6 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/10.6 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/10.6 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/10.6 MB 2.0 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/10.6 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/10.6 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/10.6 MB 2.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.6 MB 2.5 MB/s eta 0:00:04
# ...

# %% [markdown]
#  <span style='font-family:new roman'>first import all the ML labrairies that will be needed for our project</span>

# %%
import numpy as np 
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
a = np.arange(5)
print(a <=3)
# Out:
# [ True  True  True  True False]

# %%
b = np.arange(1, 11, 3)[::-1]
b
# Out:
# array([10,  7,  4,  1])
